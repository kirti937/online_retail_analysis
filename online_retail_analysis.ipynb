# %%
df_raw = pd.read_csv("C:\\Users\\kirti\\Downloads\\online_retail.csv", encoding='latin1')
print(df_raw.shape)
df_raw.head()
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df_raw.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df_raw.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID Country
# 541904  2011-12-09 12:50:00       0.85     12680.0  France
# 541905  2011-12-09 12:50:00       2.10     12680.0  France
# 541906  2011-12-09 12:50:00       4.15     12680.0  France
# 541907  2011-12-09 12:50:00       4.15     12680.0  France
# 541908  2011-12-09 12:50:00       4.95     12680.0  France

# %%
pip install datetime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime as dt
df_raw['invoice_date'] = pd.to_datetime(df_raw['invoice_date'])
df_raw['revenue'] = df_raw['quantity'] * df_raw['unit_price']
df_raw['month'] = df_raw['invoice_date'].dt.to_period('M').astype(str)
df_raw.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country  revenue  \
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom    20.34
#
#      month
# 0  2010-12
# 1  2010-12
# 2  2010-12
# 3  2010-12
# 4  2010-12

# %%
df_raw.describe(include = 'all')
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (10, 5)

df = pd.read_csv("C:\\Users\\kirti\\Downloads\\online_retail.csv", encoding='ISO-8859-1', parse_dates=['InvoiceDate'])
print(df.shape)
df.head()
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe(include='all').T
# Out:
#                 count unique                                 top    freq  \
# InvoiceNo      541909  25900                              573585    1114
# StockCode      541909   4070                              85123A    2313
# Description    540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Quantity     541909.0    NaN                                 NaN     NaN
# InvoiceDate    541909    NaN                                 NaN     NaN
# UnitPrice    541909.0    NaN                                 NaN     NaN
# CustomerID   406829.0    NaN                                 NaN     NaN
# Country        541909     38                      United Kingdom  495478
#
#                                       mean                  min  \
# InvoiceNo                              NaN                  NaN
# StockCode                              NaN                  NaN
# Description                            NaN                  NaN
# ...

# %%
missing = df.isna().sum()
missing_pct = (missing / len(df) * 100).round(2)
pd.DataFrame({'missing_count': missing, 'missing_pct': missing_pct})
# Out:
#              missing_count  missing_pct
# InvoiceNo                0         0.00
# StockCode                0         0.00
# Description           1454         0.27
# Quantity                 0         0.00
# InvoiceDate              0         0.00
# UnitPrice                0         0.00
# CustomerID          135080        24.93
# Country                  0         0.00

# %%
df['IsCancelled'] = df['InvoiceNo'].astype(str).str.startswith('C')
print('Cancelled rows:', df['IsCancelled'].sum())
print('Negative quantity rows:', (df['Quantity'] < 0).sum())
print('Zero/negative price rows:', (df['UnitPrice'] <= 0).sum())
print('Unique customers:', df['CustomerID'].nunique())
print('Unique countries:', df['Country'].nunique())
print('Date range:', df['InvoiceDate'].min(), 'to', df['InvoiceDate'].max())
# Out:
# Cancelled rows: 9288
# Negative quantity rows: 10624
# Zero/negative price rows: 2517
# Unique customers: 4372
# Unique countries: 38
# Date range: 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
clean = df[(~df['IsCancelled']) & (df['Quantity'] > 0) & (df['UnitPrice'] > 0)].copy()
clean['Revenue'] = clean['Quantity'] * clean['UnitPrice']
print('Rows before cleaning:', len(df))
print('Rows after cleaning:', len(clean))
clean.head()
# Out:
# Rows before cleaning: 541909
# Rows after cleaning: 530104
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  IsCancelled  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        False
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        False
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        False
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        False
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        False
#
#    Revenue
# 0    15.30
# 1    20.34
# ...

# %%
total_revenue = clean['Revenue'].sum()
total_orders = clean['InvoiceNo'].nunique()
total_customers = clean['CustomerID'].nunique()
avg_order_value = clean.groupby('InvoiceNo')['Revenue'].sum().mean()

print(f"Total Revenue:      £{total_revenue:,.2f}")
print(f"Total Orders:       {total_orders:,}")
print(f"Unique Customers:   {total_customers:,}")
print(f"Avg Order Value:    £{avg_order_value:,.2f}")
print(f"Avg Revenue/Customer: £{total_revenue/total_customers:,.2f}")
# Out:
# Total Revenue:      £10,666,684.54
# Total Orders:       19,960
# Unique Customers:   4,338
# Avg Order Value:    £534.40
# Avg Revenue/Customer: £2,458.89

# %%
top_products = (clean.groupby(['StockCode', 'Description'])['Revenue']
                 .sum().sort_values(ascending=False).head(10).reset_index())
top_products
# Out:
#   StockCode                         Description    Revenue
# 0       DOT                      DOTCOM POSTAGE  206248.77
# 1     22423            REGENCY CAKESTAND 3 TIER  174484.74
# 2     23843         PAPER CRAFT , LITTLE BIRDIE  168469.60
# 3    85123A  WHITE HANGING HEART T-LIGHT HOLDER  104340.29
# 4     47566                       PARTY BUNTING   99504.33
# 5    85099B             JUMBO BAG RED RETROSPOT   94340.05
# 6     23166      MEDIUM CERAMIC TOP STORAGE JAR   81700.92
# 7         M                              Manual   78110.27
# 8      POST                             POSTAGE   78101.88
# 9     23084                  RABBIT NIGHT LIGHT   66964.99

# %%
fig, ax = plt.subplots()
ax.barh(top_products['Description'].str[:30][::-1], top_products['Revenue'][::-1], color='#2b6cb0')
ax.set_xlabel('Revenue (£)')
ax.set_title('Top 10 Products by Revenue')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'£{x:,.0f}'))
plt.tight_layout()
plt.show()

# %%
country_rev = clean.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
country_rev.head(10)
# Out:
# Country
# United Kingdom    9025222.084
# Netherlands        285446.340
# EIRE               283453.960
# Germany            228867.140
# France             209715.110
# Australia          138521.310
# Spain               61577.110
# Switzerland         57089.900
# Belgium             41196.340
# Sweden              38378.330
# Name: Revenue, dtype: float64

# %%
fig, ax = plt.subplots()
top_countries = country_rev.head(10)
ax.bar(top_countries.index, top_countries.values, color='#2f855a')
ax.set_ylabel('Revenue (£)')
ax.set_title('Top 10 Countries by Revenue')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'£{x:,.0f}'))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
clean['YearMonth'] = clean['InvoiceDate'].dt.to_period('M').astype(str)
monthly = clean.groupby('YearMonth')['Revenue'].sum()
monthly
# Out:
# YearMonth
# 2010-12     823746.140
# 2011-01     691364.560
# 2011-02     523631.890
# 2011-03     717639.360
# 2011-04     537808.621
# 2011-05     770536.020
# 2011-06     761739.900
# 2011-07     719221.191
# 2011-08     759138.380
# 2011-09    1058590.172
# 2011-10    1154979.300
# 2011-11    1509496.330
# 2011-12     638792.680
# Name: Revenue, dtype: float64

# %%
fig, ax = plt.subplots()
ax.plot(monthly.index, monthly.values, marker='o', color='#c05621')
ax.set_title('Monthly Revenue Trend')
ax.set_ylabel('Revenue (£)')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'£{x:,.0f}'))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
clean['DayOfWeek'] = clean['InvoiceDate'].dt.day_name()
clean['Hour'] = clean['InvoiceDate'].dt.hour

order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
dow = clean.groupby('DayOfWeek')['Revenue'].sum().reindex(order)

fig, ax = plt.subplots()
ax.bar(dow.index, dow.values, color='#6b46c1')
ax.set_title('Revenue by Day of Week')
ax.set_ylabel('Revenue (£)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
snapshot_date = clean['InvoiceDate'].max() + pd.Timedelta(days=1)

rfm = clean.groupby('CustomerID').agg(
    Recency=('InvoiceDate', lambda x: (snapshot_date - x.max()).days),
    Frequency=('InvoiceNo', 'nunique'),
    Monetary=('Revenue', 'sum')
).reset_index()

rfm['R_Score'] = pd.qcut(rfm['Recency'], 4, labels=[4,3,2,1]).astype(int)
rfm['F_Score'] = pd.qcut(rfm['Frequency'].rank(method='first'), 4, labels=[1,2,3,4]).astype(int)
rfm['M_Score'] = pd.qcut(rfm['Monetary'], 4, labels=[1,2,3,4]).astype(int)
rfm['RFM_Score'] = rfm['R_Score'] + rfm['F_Score'] + rfm['M_Score']

def segment(score):
    if score >= 10: return 'Champions'
    elif score >= 8: return 'Loyal'
    elif score >= 6: return 'Potential'
    elif score >= 4: return 'At Risk'
    else: return 'Lost'

rfm['Segment'] = rfm['RFM_Score'].apply(segment)
rfm.sort_values('Monetary', ascending=False).head(10)
# Out:
#       CustomerID  Recency  Frequency   Monetary  R_Score  F_Score  M_Score  \
# 1689     14646.0        2         73  280206.02        4        4        4
# 4201     18102.0        1         60  259657.30        4        4        4
# 3728     17450.0        8         46  194550.79        4        4        4
# 3008     16446.0        1          2  168472.50        4        2        4
# 1879     14911.0        1        201  143825.06        4        4        4
# 55       12415.0       24         21  124914.53        3        4        4
# 1333     14156.0       10         55  117379.63        4        4        4
# 3771     17511.0        3         31   91062.38        4        4        4
# 2702     16029.0       39         63   81024.84        3        4        4
# 0        12346.0      326          1   77183.60        1        1        4
#
#       RFM_Score    Segment
# 1689         12  Champions
# 4201         12  Champions
# 3728         12  Champions
# 3008         10  Champions
# ...

# %%
seg_counts = rfm['Segment'].value_counts()
fig, ax = plt.subplots()
ax.pie(seg_counts.values, labels=seg_counts.index, autopct='%1.1f%%',
       colors=['#2b6cb0','#2f855a','#c05621','#c53030','#805ad5'])
ax.set_title('Customer Segments (RFM)')
plt.tight_layout()
plt.show()

# %%
top_customers = clean.groupby('CustomerID')['Revenue'].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194550.79
# 16446.0    168472.50
# 14911.0    143825.06
# 12415.0    124914.53
# 14156.0    117379.63
# 17511.0     91062.38
# 16029.0     81024.84
# 12346.0     77183.60
# Name: Revenue, dtype: float64

# %%
clean_export = clean[['InvoiceNo','StockCode','Description','Quantity','InvoiceDate',
                       'UnitPrice','CustomerID','Country','Revenue','YearMonth','DayOfWeek','Hour']]
clean_export.to_csv('online_retail_clean.csv', index=False)
rfm.to_csv('rfm_segments.csv', index=False)
print('Exported: online_retail_clean.csv, rfm_segments.csv')
# Out:
# Exported: online_retail_clean.csv, rfm_segments.csv
